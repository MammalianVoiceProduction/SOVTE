# %%
# %autocall 2
# Out:
# Automatic calling is: Full

# %%
# %matplotlib -l
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'webagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib widget

# %%
import matplotlib as mpl

import matplotlib.pyplot as plt

# %%
plt.interactive(False)

plt.ioff()

# %%
import os, sys

import glob, gc

import numpy as np
import time

import pprint

from importlib import reload

import ipython_memory_usage

# %%
# %ipython_memory_usage_start
# Out:
# 'memory profile enabled'
# In [7] used 0.0664 MiB RAM in 0.52s, peaked 0.00 MiB above current, total RAM usage 98.82 MiB

# %%
gc.collect()
# Out:
# 4
# In [8] used 0.0273 MiB RAM in 0.14s, peaked 0.00 MiB above current, total RAM usage 98.85 MiB

# %%
cinelist = []
mrawlist = []

for root, dirs, files in os.walk("c:/users/m142519"):
    for f in files:
        if f.endswith('.mraw'):
            mrawlist.append(os.path.join(root, f))
        if f.endswith('.cine'):
            cinelist.append(os.path.join(root, f))
# Out:
# In [9] used 0.8594 MiB RAM in 2.81s, peaked 0.00 MiB above current, total RAM usage 99.71 MiB

# %%
[print(p) for p in cinelist];
# Out:
# c:/users/m142519\Desktop\Cine Examples\Cine_2_Y20230325H133225.855530000.cine
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\2019-03-20-60s80s.8bit.cine
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\2019-03-20-token-1-2-5-7.packed.cine
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\flex2522239.cine
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\flex2623677.cine
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\flex2855385.cine
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFtype4-300Wlight100percent.cine
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFtype4-300Wlight100percentrepeat.cine
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFtype4-300WlightD2inches.cine
# ...

# %%
[print(p) for p in mrawlist];
# Out:
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFType4-300WLight100percent.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFType4-300WLightD2inches.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFType4-300WlightD2inchesNoSoftwareGain.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-300WLight100percent\OlympusENFType4-300WlightD2inchesWithSoftwareGain.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-Light100percent\OlympusENFType4-Light100percent.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-Light50percent\OlympusENFType4-Light50percent.mraw
# c:/users/m142519\Desktop\Cine Examples\Sunoptic Titan X450\OlympusENFType4-Light75percent\OlympusENFType4-Light75percent.mraw
# ...

# %%
for root, dirs, files in os.walk("H:/"):
    for f in files:
        if f.endswith('.cine'):
            cinelist.append(os.path.join(root, f))
        if f.endswith('.mraw'):
            mrawlist.append(os.path.join(root, f))    

for root, dirs, files in os.walk("Z:/"):
    for f in files:
        if f.endswith('.cine'):
            cinelist.append(os.path.join(root, f))
        if f.endswith('.mraw'):
            mrawlist.append(os.path.join(root, f))
# Out:
# In [12] used 2.3203 MiB RAM in 665.30s, peaked 0.00 MiB above current, total RAM usage 102.03 MiB

# %%
import pickle
# Out:
# In [15] used 1.8242 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 104.31 MiB

# %%
pickle.dump(dict(cine = cinelist, mraw = mrawlist), open("highspeedfiles.pickle", 'wb'))
# Out:
# In [16] used 7.2773 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 111.59 MiB

# %%
testpickle = pickle.load(open('highspeedfiles.pickle', 'rb'))
# Out:
# In [17] used 0.2500 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 111.84 MiB

# %%
pwd
# Out:
# 'C:\\Users\\m142519\\Desktop\\Jupyter Notebooks'
# In [11] used -0.0117 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 99.71 MiB

# %%
ls "C:\Users\m142519\python\neuromuscular\tools\cine.py"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8C22-592F
#
#  Directory of C:\Users\m142519\python\neuromuscular\tools
#
# 10/24/2023  11:13 AM            28,406 cine.py
#                1 File(s)         28,406 bytes
#                0 Dir(s)  279,615,107,072 bytes free
# In [15] used -0.0547 MiB RAM in 0.12s, peaked 0.00 MiB above current, total RAM usage 99.71 MiB

# %%
ls "H:\python\neuromuscular\tools\cine.py"
# Out:
#  Volume in drive H is users03
#  Volume Serial Number is 009A-9A03
#
#  Directory of H:\python\neuromuscular\tools
#
# 02/05/2020  03:08 PM            28,074 cine.py
#                1 File(s)         28,074 bytes
#                0 Dir(s)  1,791,518,456,045,568 bytes free
# In [17] used 0.0039 MiB RAM in 0.24s, peaked 0.04 MiB above current, total RAM usage 99.69 MiB

# %%
mylibrarypaths = ["C:\\Users\\m142519\\python",
                  "C:\\Users\\m142519\\python\\neuromuscular\\tools",
                  # "H:\\python", 
                  # "H:\\python\\neuromuscular\\tools", 
                  "C:\\Users\\m142519\\Documents\\Phantom\\PhSDK804\\Python\\examples"]

for p in mylibrarypaths:
    if os.path.isdir(p):
        if p not in sys.path:
            sys.path.append(p)

pprint.pprint(sys.path)
# Out:
# ['C:\\Users\\m142519\\Desktop\\Jupyter Notebooks',
#  'C:\\Program Files\\Python311\\python311.zip',
#  'C:\\Program Files\\Python311\\DLLs',
#  'C:\\Program Files\\Python311\\Lib',
#  'C:\\Program Files\\Python311',
#  '',
#  'C:\\Program Files\\Python311\\Lib\\site-packages',
#  'C:\\Program Files\\Python311\\Lib\\site-packages\\win32',
#  'C:\\Program Files\\Python311\\Lib\\site-packages\\win32\\lib',
#  'C:\\Program Files\\Python311\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\m142519\\python',
#  'C:\\Users\\m142519\\python\\neuromuscular\\tools',
#  'C:\\Users\\m142519\\Documents\\Phantom\\PhSDK804\\Python\\examples']
# In [20] used -0.0156 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 118.10 MiB

# %% [markdown]
# # Vision Research pyphantom

# %%
import pyphantom

# import modules, NOT classes (UPPER CASE)
# from pyphantom import phantom, cine, camera, utils

from Camera_Selector_Fn import camera_selector

import cv2

import keyboard
# Out:
# In [71] used 124.6328 MiB RAM in 4.89s, peaked 0.00 MiB above current, total RAM usage 262.54 MiB

# %%
ph = pyphantom.phantom.Phantom()
# Out:
# In [72] used -22.9531 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 239.59 MiB

# %%
# adding simulated cameras to fake record with

# color sim camera
# ph.add_simulated_camera(sensor_type = utils.SensorTypeEnum.COLOR)
# cam_Color = ph.Camera(ph.camera_count - 1)

# mono sim camera
ph.add_simulated_camera(sensor_type = pyphantom.utils.SensorTypeEnum.MONO)
cam_Mono = ph.Camera(ph.camera_count - 1)

# use real camera
# cam_Mono = ph.Camera(0)
# Out:
# In [74] used 23.4883 MiB RAM in 0.12s, peaked 0.00 MiB above current, total RAM usage 263.52 MiB

# %%
# unregister camera objects
cam_Mono.close()
# Out:
# In [75] used 0.0039 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 263.53 MiB

# %%
cam_Mono.delete()
# Out:
# In [77] used 2.8711 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 266.40 MiB

# %%
del cam_Mono
# Out:
# In [79] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 266.40 MiB

# %%
gc.collect()
# Out:
# 1796
# In [81] used 0.0000 MiB RAM in 0.18s, peaked 0.00 MiB above current, total RAM usage 266.40 MiB

# %%
ph.camera_count
# Out:
# 0
# In [84] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 234.88 MiB

# %%
filename = ph.file_select_dialog()

print(filename)

cinefile = cine.Cine.from_filepath(filename)

Nframes = 10

# framerange = utils.FrameRange(cinefile.range.last_image - 1, cinefile.range.last_image)
framerange = utils.FrameRange(0, Nframes - 1)

# %%
filename = 'C:\\Users\\m142519\\Desktop\\Cine Examples\\Cine_2_Y20230325H133225.855530000.cine'

# %%
filename

# %%
framerange

# %%
# %%timeit

frames = cinefile.get_images(framerange)

# %%
frames

# %%
# unregister phantom() objects
ph.close()
# Out:
# In [83] used -31.5312 MiB RAM in 1.03s, peaked 31.53 MiB above current, total RAM usage 234.88 MiB

# %% [markdown]
# # My own cine library

# %%
import cine as mycine
mycine = reload(mycine)
# Out:
# In [51] used 0.0039 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 136.94 MiB

# %%
mycine
# Out:
# <module 'cine' from 'C:\\Users\\m142519\\python\\neuromuscular\\tools\\cine.py'>
# In [50] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.93 MiB

# %%
filename = "c:/users/m142519/Desktop/Cine Examples/Spasmodic Dysphonia/2019-03-20-token-1-2-5-7.packed.cine"
# Out:
# In [59] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
os.path.dirname(filename)
# Out:
# 'c:/users/m142519/Desktop/Cine Examples/Spasmodic Dysphonia'
# In [60] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
os.path.basename(filename)
# Out:
# '2019-03-20-token-1-2-5-7.packed.cine'
# In [61] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
c = mycine.Cine(initialdir = os.path.dirname(filename), cinefilename = os.path.basename(filename), debug = False)
# Out:
# invalid shape in fixed-type tuple: dtype size in bytes must fit into a C int.
# problem with allframes_type, probably too large:
# predicted size [GigaBytes]  58.9938662648201
#
# In [62] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
c.bitmapheader['bicompression']
# Out:
# 256
# In [63] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
c.setup['realbpp']
# Out:
# 10
# In [64] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 136.46 MiB

# %%
# %%timeit
Nframes = 10
frames = c.getNframes(firstframe = 0, Nframes = Nframes)
# Out:
# 25.8 ms ± 453 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# In [66] used 0.0273 MiB RAM in 2.21s, peaked 38.01 MiB above current, total RAM usage 137.90 MiB

# %%
del c
# Out:
# In [67] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 137.90 MiB

# %%
gc.collect()
# Out:
# 1101
# In [68] used 0.0000 MiB RAM in 0.17s, peaked 0.00 MiB above current, total RAM usage 137.90 MiB

# %%
for f in cinelist:
    print(f)
    
    c = mycine.Cine(initialdir = os.path.dirname(f), cinefilename = os.path.basename(f), debug = False)
    
    print("realbpp: ", c.setup['realbpp'], "bicompression: ", c.bitmapheader['bicompression'])
    print('#' * 40)
    print()
    
    c.file.close()
    del c
# Out:
# c:/users/m142519\Desktop\Cine Examples\Cine_2_Y20230325H133225.855530000.cine
# realbpp:  12 bicompression:  1024
# ########################################
#
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\2019-03-20-60s80s.8bit.cine
# invalid shape in fixed-type tuple: dtype size in bytes must fit into a C int.
# problem with allframes_type, probably too large:
# predicted size [GigaBytes]  47.195198357105255
#
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ATTENTION: The cine was not triggered at the first image!
# imagecount:  70696
# posttrigger:  1
# firstimageno:  -70695
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# realbpp:  8 bicompression:  0
# ########################################
#
# c:/users/m142519\Desktop\Cine Examples\Spasmodic Dysphonia\2019-03-20-token-1-2-5-7.packed.cine
# invalid shape in fixed-type tuple: dtype size in bytes must fit into a C int.
# problem with allframes_type, probably too large:
# predicted size [GigaBytes]  58.9938662648201
#
# ...
